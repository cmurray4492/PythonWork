# %% [markdown]
# # Regular Expression Book
# **Book**: Simpliying Regular Expressions Using Python
#
# **Author**: Abhishek Singh

# %% [markdown]
# ## Base First Two Lines

# %%
import re
pattern = re.compile(r"")

# %% [markdown]
# ### Sub Function

# %% [markdown]
# The **sub** function below is used with "**+**" on the pattern and it replaces all digits in sequence with one "_"

# %%
import re
pattern = re.compile(r"")
my_string = input("Please enter a string: ")
pattern = re.compile(r"[0-9]+")
result = pattern.sub("_", my_string)
print(result)
# Out:
# Please enter a string:  cmurray4492
# cmurray_

# %% [markdown]
# The same **sub** function repalces each set of matches with an "_".

# %%
import re
pattern = re.compile(r"")
my_string = input("Please enter a string: ")
pattern = re.compile(r"[0-9]+")
result = pattern.sub("_", my_string)
print(result)
# Out:
# Please enter a string:  cmur44ray4492
# cmur_ray_

# %% [markdown]
# Not using the "**+**" quanifier repalces each digit with an "_".

# %%
import re
pattern = re.compile(r"")
my_string = input("Please enter a string: ")
pattern = re.compile(r"[0-9]")
result = pattern.sub("_", my_string)
print(result)
# Out:
# Please enter a string:  cmurray4492
# cmurray____

# %% [markdown]
# ### Special Sequences
# - **.**  Matches any single character except the newline character.
# - **\d** Matches and digit [0-9]
# - **\D** Matches any non-digit character [^0-9]
# - **\s** Matches any whitespace character [\t\n\r\f\v]
# - **\S** Matches any non-whitespace character [^\t\n\r\f\v]
# - **\w** Matches any alphanumeric chacter [a-zA-Z0-9]
# - **\W** Matches any non-alphanumeric chacter [^a-zA-Z0-9]
# - **\A** Returns a match if the specified characters are at the beginning of a string.
# - **\b** Returns a match where the specified characters are at the beginning or end of a word.
# - **\B** Returns a match where the specified characters are NOT at the beginning or end of a word.
# - **\Z** Returns a match if the specified characters are at the end of a string.

# %% [markdown]
# Using the **sub** function with **\d** and the quantifer **+**

# %%
import re
pattern = re.compile(r"")
my_string = input("Please enter a string: ")
pattern = re.compile(r"[\d+]")
result = pattern.sub("$", my_string)
print(result)
# Out:
# Please enter a string:  c2murray4492
# c$murray$$$$

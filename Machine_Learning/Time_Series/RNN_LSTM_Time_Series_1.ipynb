# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
import time
import tensorflow as tf
import os

from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

warnings.filterwarnings("ignore")

# %%
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.18.0

# %%
'''
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)
''';

# %%
start_time = time.time()

# %%
df = pd.read_csv("C:\\Users\\South\\.keras\\datasets\\jena_climate_2009_2016a.csv")
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
def plot_predictions1(model, X, y, start=0, end=150):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 5        94.40          3.33          3.14          0.19       1.96
# 11       93.20          3.12          2.90          0.21       1.81
# 17       93.50          3.13          2.93          0.20       1.83
# 23       92.60          3.07          2.85          0.23       1.78
# 29       92.20          2.94          2.71          0.23       1.69
# ...        ...           ...           ...           ...        ...
# 420521   72.00          5.69          4.09          1.59       2.54
# 420527   66.29          5.51          3.65          1.86       2.27
# 420533   72.90          4.99          3.64          1.35       2.26
# 420539   72.30          4.93          3.57          1.37       2.22
# 420545   72.60          4.56          3.31          1.25       2.06
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5                  3.15       1307.86      0.21           0.63     192.7
# 11                 2.91       1312.25      0.25           0.63     190.3
# 17                 2.94       1312.18      0.18           0.63     167.2
# 23                 2.85       1313.61      0.10           0.38     240.0
# 29                 2.71       1317.19      0.40           0.88     157.0
# ...                 ...           ...       ...            ...       ...
# 420521             4.08       1280.70      0.87           1.36     190.6
# 420527             3.65       1281.87      1.02           1.92     225.4
# 420533             3.63       1288.02      0.71           1.56     158.7
# 420539             3.57       1288.03      0.35           0.68     216.7
# 420545             3.31       1292.41      0.56           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# 2009-01-01 13:00:00  01.01.2009 13:00:00   1000.03     -5.89    267.27
# 2009-01-01 14:00:00  01.01.2009 14:00:00    999.81     -5.94    267.24
# 2009-01-01 15:00:00  01.01.2009 15:00:00    999.88     -5.69    267.48
# 2009-01-01 16:00:00  01.01.2009 16:00:00    999.94     -5.40    267.76
# 2009-01-01 17:00:00  01.01.2009 17:00:00   1000.17     -5.37    267.78
# 2009-01-01 18:00:00  01.01.2009 18:00:00   1000.16     -5.25    267.90
# 2009-01-01 19:00:00  01.01.2009 19:00:00   1000.22     -5.11    268.03
# 2009-01-01 20:00:00  01.01.2009 20:00:00   1000.22     -4.90    268.24
# 2009-01-01 21:00:00  01.01.2009 21:00:00   1000.19     -4.80    268.35
# 2009-01-01 22:00:00  01.01.2009 22:00:00   1000.00     -4.50    268.66
# 2009-01-01 23:00:00  01.01.2009 23:00:00    999.77     -4.47    268.71
# 2009-01-02 00:00:00  02.01.2009 00:00:00    999.59     -4.54    268.65
# 2009-01-02 01:00:00  02.01.2009 01:00:00    999.34     -4.44    268.77
# 2009-01-02 02:00:00  02.01.2009 02:00:00    998.93     -4.29    268.95
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# 2009-01-01 01:00:00        -8.78    94.4          3.33          3.14
# 2009-01-01 02:00:00        -9.77    93.2          3.12          2.90
# 2009-01-01 03:00:00        -9.66    93.5          3.13          2.93
# 2009-01-01 04:00:00       -10.02    92.6          3.07          2.85
# 2009-01-01 05:00:00       -10.65    92.2          2.94          2.71
# 2009-01-01 06:00:00       -10.62    92.7          2.93          2.71
# 2009-01-01 07:00:00       -10.10    92.9          3.04          2.83
# 2009-01-01 08:00:00        -9.05    92.8          3.31          3.07
# 2009-01-01 09:00:00        -8.84    91.2          3.43          3.13
# 2009-01-01 10:00:00        -8.17    91.6          3.60          3.30
# 2009-01-01 11:00:00        -8.66    90.7          3.50          3.17
# 2009-01-01 12:00:00        -8.28    89.6          3.64          3.27
# 2009-01-01 13:00:00        -7.46    88.6          3.93          3.48
# 2009-01-01 14:00:00        -7.43    89.1          3.92          3.49
# 2009-01-01 15:00:00        -7.00    90.4          3.99          3.61
# 2009-01-01 16:00:00        -6.86    89.4          4.08          3.65
# 2009-01-01 17:00:00        -6.82    89.4          4.09          3.66
# 2009-01-01 18:00:00        -6.75    89.1          4.13          3.68
# 2009-01-01 19:00:00        -6.57    89.4          4.17          3.73
# 2009-01-01 20:00:00        -6.38    89.3          4.24          3.79
# 2009-01-01 21:00:00        -6.14    90.2          4.27          3.85
# 2009-01-01 22:00:00        -5.82    90.4          4.37          3.95
# 2009-01-01 23:00:00        -5.84    90.1          4.38          3.95
# 2009-01-02 00:00:00        -5.46    93.2          4.36          4.06
# 2009-01-02 01:00:00        -5.19    94.4          4.39          4.15
# 2009-01-02 02:00:00        -5.04    94.5          4.44          4.20
#
#                      VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# Date Time
# 2009-01-01 01:00:00          0.19       1.96             3.15       1307.86
# 2009-01-01 02:00:00          0.21       1.81             2.91       1312.25
# 2009-01-01 03:00:00          0.20       1.83             2.94       1312.18
# 2009-01-01 04:00:00          0.23       1.78             2.85       1313.61
# 2009-01-01 05:00:00          0.23       1.69             2.71       1317.19
# 2009-01-01 06:00:00          0.21       1.69             2.72       1317.71
# 2009-01-01 07:00:00          0.22       1.76             2.83       1315.98
# 2009-01-01 08:00:00          0.24       1.92             3.08       1311.65
# 2009-01-01 09:00:00          0.30       1.95             3.13       1310.14
# 2009-01-01 10:00:00          0.30       2.05             3.29       1307.76
# 2009-01-01 11:00:00          0.33       1.97             3.17       1310.43
# 2009-01-01 12:00:00          0.38       2.03             3.26       1306.98
# 2009-01-01 13:00:00          0.45       2.17             3.48       1301.73
# 2009-01-01 14:00:00          0.43       2.17             3.49       1301.67
# 2009-01-01 15:00:00          0.38       2.25             3.61       1300.51
# 2009-01-01 16:00:00          0.43       2.27             3.65       1299.17
# 2009-01-01 17:00:00          0.43       2.28             3.66       1299.27
# 2009-01-01 18:00:00          0.45       2.29             3.68       1298.68
# 2009-01-01 19:00:00          0.44       2.32             3.73       1298.07
# 2009-01-01 20:00:00          0.45       2.36             3.78       1297.05
# 2009-01-01 21:00:00          0.42       2.40             3.85       1296.45
# 2009-01-01 22:00:00          0.42       2.46             3.95       1294.72
# 2009-01-01 23:00:00          0.43       2.46             3.95       1294.29
# 2009-01-02 00:00:00          0.30       2.53             4.06       1294.33
# 2009-01-02 01:00:00          0.25       2.58             4.15       1293.47
# 2009-01-02 02:00:00          0.24       2.62             4.20       1292.22
#
#                      wv (m/s)  max. wv (m/s)  wd (deg)
# Date Time
# 2009-01-01 01:00:00      0.21           0.63     192.7
# 2009-01-01 02:00:00      0.25           0.63     190.3
# 2009-01-01 03:00:00      0.18           0.63     167.2
# 2009-01-01 04:00:00      0.10           0.38     240.0
# 2009-01-01 05:00:00      0.40           0.88     157.0
# 2009-01-01 06:00:00      0.05           0.50     146.0
# 2009-01-01 07:00:00      2.08           2.88     348.8
# 2009-01-01 08:00:00      0.72           1.25     213.9
# 2009-01-01 09:00:00      0.34           0.63     202.2
# 2009-01-01 10:00:00      1.45           3.00     292.6
# 2009-01-01 11:00:00      1.91           3.38     269.6
# 2009-01-01 12:00:00      1.84           2.63     184.4
# 2009-01-01 13:00:00      0.57           1.25     187.3
# 2009-01-01 14:00:00      1.25           2.00     144.0
# 2009-01-01 15:00:00      1.17           1.88     134.9
# 2009-01-01 16:00:00      1.40           2.13     145.5
# 2009-01-01 17:00:00      0.85           1.63     142.2
# 2009-01-01 18:00:00      0.55           1.00     183.7
# 2009-01-01 19:00:00      0.41           0.75     176.7
# 2009-01-01 20:00:00      0.68           1.13     195.2
# 2009-01-01 21:00:00      0.44           0.75     206.3
# 2009-01-01 22:00:00      0.33           0.63     175.7
# 2009-01-01 23:00:00      0.65           1.00     219.3
# 2009-01-02 00:00:00      0.41           0.88     155.0
# 2009-01-02 01:00:00      0.28           1.00     148.1
# 2009-01-02 02:00:00      0.49           0.88     209.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 70091 entries, 2009-01-01 01:00:00 to 2016-12-31 23:10:00
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date Time        70091 non-null  object
#  1   p (mbar)         70091 non-null  float64
#  2   T (degC)         70091 non-null  float64
#  3   Tpot (K)         70091 non-null  float64
#  4   Tdew (degC)      70091 non-null  float64
#  5   rh (%)           70091 non-null  float64
#  6   VPmax (mbar)     70091 non-null  float64
#  7   VPact (mbar)     70091 non-null  float64
#  8   VPdef (mbar)     70091 non-null  float64
#  9   sh (g/kg)        70091 non-null  float64
#  10  H2OC (mmol/mol)  70091 non-null  float64
#  11  rho (g/m**3)     70091 non-null  float64
#  12  wv (m/s)         70091 non-null  float64
#  13  max. wv (m/s)    70091 non-null  float64
#  14  wd (deg)         70091 non-null  float64
# dtypes: float64(14), object(1)
# memory usage: 8.6+ MB

# %%
temp = df['T (degC)']
temp.plot();

# %%
def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %% [markdown]
# ## Base Univarite Time Series Analysis

# %%
model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 40.9585 - root_mean_squared_error: 6.3999 - val_loss: 1.4464 - val_root_mean_squared_error: 1.2027
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 2.7760 - root_mean_squared_error: 1.6661 - val_loss: 0.6142 - val_root_mean_squared_error: 0.7837
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 1.0566 - root_mean_squared_error: 1.0279 - val_loss: 0.5374 - val_root_mean_squared_error: 0.7331
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.7719 - root_mean_squared_error: 0.8786 - val_loss: 0.5106 - val_root_mean_squared_error: 0.7146
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.7005 - root_mean_squared_error: 0.8370 - val_loss: 0.5038 - val_root_mean_squared_error: 0.7098
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6741 - root_mean_squared_error: 0.8210 - val_loss: 0.5134 - val_root_mean_squared_error: 0.7165
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6610 - root_mean_squared_error: 0.8130 - val_loss: 0.4923 - val_root_mean_squared_error: 0.7016
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6554 - root_mean_squared_error: 0.8096 - val_loss: 0.4948 - val_root_mean_squared_error: 0.7034
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6505 - root_mean_squared_error: 0.8065 - val_loss: 0.4937 - val_root_mean_squared_error: 0.7026
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6474 - root_mean_squared_error: 0.8046 - val_loss: 0.4957 - val_root_mean_squared_error: 0.7040

# %%
model1 = load_model('model1.keras')

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 778us/step
#        Train Predictions  Actuals
# 0              -9.659075    -9.67
# 1              -9.519722    -9.17
# 2              -8.760187    -8.10
# 3              -7.428800    -7.66
# 4              -7.284288    -7.04
# ...                  ...      ...
# 59995           6.070039     6.07
# 59996           7.214468     9.88
# 59997          12.294974    13.53
# 59998          16.096052    15.43
# 59999          16.340326    15.54
#
# [60000 rows x 2 columns]

# %%
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100]);

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Val Predictions  Actuals
# 0           15.537853    14.02
# 1           13.294585    13.67
# 2           13.030696    12.27
# 3           11.562899    11.19
# 4           10.443101    10.85
# ...               ...      ...
# 4995        17.463535    18.27
# 4996        17.465218    17.85
# 4997        17.258389    16.65
# 4998        15.812042    15.85
# 4999        15.039755    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100]);

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
#       Test Predictions  Actuals
# 0            14.371810    13.99
# 1            13.247904    13.46
# 2            12.858538    12.93
# 3            12.459692    12.43
# 4            12.005833    12.17
# ...                ...      ...
# 5081         -1.029383    -0.98
# 5082         -1.385687    -1.40
# 5083         -1.611780    -2.75
# 5084         -3.345017    -2.89
# 5085         -3.117833    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %%
plot_predictions1(model1, X_test1, y_test1)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# (      Predictions  Actuals
#  0       14.371810    13.99
#  1       13.247904    13.46
#  2       12.858538    12.93
#  3       12.459692    12.43
#  4       12.005833    12.17
#  ...           ...      ...
#  5081    -1.029383    -0.98
#  5082    -1.385687    -1.40
#  5083    -1.611780    -2.75
#  5084    -3.345017    -2.89
#  5085    -3.117833    -3.93
#
#  [5086 rows x 2 columns],
#  0.6408303980884851)

# %% [markdown]
# ## Convolutional Neural Network Time Series Analysis - Model 2

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 4, 64)               │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │           2,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,257 (8.82 KB)
#  Trainable params: 2,257 (8.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('model2.keras', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=15, callbacks=[cp2]) ;
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 6.9634 - root_mean_squared_error: 2.6388 - val_loss: 1.0386 - val_root_mean_squared_error: 1.0191
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 1.1237 - root_mean_squared_error: 1.0600 - val_loss: 0.7711 - val_root_mean_squared_error: 0.8781
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.8504 - root_mean_squared_error: 0.9222 - val_loss: 0.6078 - val_root_mean_squared_error: 0.7796
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.7408 - root_mean_squared_error: 0.8607 - val_loss: 0.5960 - val_root_mean_squared_error: 0.7720
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6983 - root_mean_squared_error: 0.8356 - val_loss: 0.5243 - val_root_mean_squared_error: 0.7241
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6786 - root_mean_squared_error: 0.8238 - val_loss: 0.5112 - val_root_mean_squared_error: 0.7149
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6708 - root_mean_squared_error: 0.8190 - val_loss: 0.5254 - val_root_mean_squared_error: 0.7248
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6687 - root_mean_squared_error: 0.8177 - val_loss: 0.5009 - val_root_mean_squared_error: 0.7078
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6650 - root_mean_squared_error: 0.8154 - val_loss: 0.5418 - val_root_mean_squared_error: 0.7361
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6615 - root_mean_squared_error: 0.8133 - val_loss: 0.4966 - val_root_mean_squared_error: 0.7047
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6610 - root_mean_squared_error: 0.8130 - val_loss: 0.4935 - val_root_mean_squared_error: 0.7025
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6583 - root_mean_squared_error: 0.8113 - val_loss: 0.5130 - val_root_mean_squared_error: 0.7163
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6578 - root_mean_squared_error: 0.8111 - val_loss: 0.5162 - val_root_mean_squared_error: 0.7185
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.6593 - root_mean_squared_error: 0.8119 - val_loss: 0.4919 - val_root_mean_squared_error: 0.7014
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.6569 - root_mean_squared_error: 0.8105 - val_loss: 0.5083 - val_root_mean_squared_error: 0.7130

# %%
plot_predictions1(model2, X_test1, y_test1)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step
# (      Predictions  Actuals
#  0       14.563994    13.99
#  1       13.359207    13.46
#  2       13.063730    12.93
#  3       12.627373    12.43
#  4       12.185989    12.17
#  ...           ...      ...
#  5081    -0.855739    -0.98
#  5082    -1.368550    -1.40
#  5083    -1.576488    -2.75
#  5084    -3.250769    -2.89
#  5085    -3.179527    -3.93
#
#  [5086 rows x 2 columns],
#  0.6429623164897658)

# %% [markdown]
# ## GRO Model For Time Series Analysis - Model 3

# %%
model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 64)                  │          12,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,393 (52.32 KB)
#  Trainable params: 13,393 (52.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp3 = ModelCheckpoint('model3.keras', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=15, callbacks=[cp3]);
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 34.0709 - root_mean_squared_error: 5.8370 - val_loss: 1.0522 - val_root_mean_squared_error: 1.0258
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.8049 - root_mean_squared_error: 1.3435 - val_loss: 0.6262 - val_root_mean_squared_error: 0.7913
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.8818 - root_mean_squared_error: 0.9390 - val_loss: 0.5263 - val_root_mean_squared_error: 0.7254
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.7082 - root_mean_squared_error: 0.8416 - val_loss: 0.5068 - val_root_mean_squared_error: 0.7119
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6660 - root_mean_squared_error: 0.8161 - val_loss: 0.5001 - val_root_mean_squared_error: 0.7072
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6509 - root_mean_squared_error: 0.8068 - val_loss: 0.5086 - val_root_mean_squared_error: 0.7132
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6456 - root_mean_squared_error: 0.8035 - val_loss: 0.5046 - val_root_mean_squared_error: 0.7104
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6421 - root_mean_squared_error: 0.8013 - val_loss: 0.5261 - val_root_mean_squared_error: 0.7253
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6406 - root_mean_squared_error: 0.8004 - val_loss: 0.4970 - val_root_mean_squared_error: 0.7050
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6383 - root_mean_squared_error: 0.7989 - val_loss: 0.4900 - val_root_mean_squared_error: 0.7000
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6374 - root_mean_squared_error: 0.7984 - val_loss: 0.4947 - val_root_mean_squared_error: 0.7034
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6368 - root_mean_squared_error: 0.7980 - val_loss: 0.4913 - val_root_mean_squared_error: 0.7009
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6353 - root_mean_squared_error: 0.7970 - val_loss: 0.4920 - val_root_mean_squared_error: 0.7014
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6349 - root_mean_squared_error: 0.7968 - val_loss: 0.4878 - val_root_mean_squared_error: 0.6984
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6346 - root_mean_squared_error: 0.7966 - val_loss: 0.5224 - val_root_mean_squared_error: 0.7228

# %%
plot_predictions1(model3, X_test1, y_test1)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (      Predictions  Actuals
#  0       14.568998    13.99
#  1       13.422175    13.46
#  2       13.081672    12.93
#  3       12.672831    12.43
#  4       12.236909    12.17
#  ...           ...      ...
#  5081    -0.980782    -0.98
#  5082    -1.471683    -1.40
#  5083    -1.514006    -2.75
#  5084    -3.143362    -2.89
#  5085    -3.210913    -3.93
#
#  [5086 rows x 2 columns],
#  0.6003530506654903)

# %%
temp_df = pd.DataFrame({'Temperature':temp})
temp_df['Seconds'] = temp_df.index.map(pd.Timestamp.timestamp)
temp_df
# Out:
#                      Temperature       Seconds
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09
# 2009-01-01 02:00:00        -8.88  1.230775e+09
# 2009-01-01 03:00:00        -8.81  1.230779e+09
# 2009-01-01 04:00:00        -9.05  1.230782e+09
# 2009-01-01 05:00:00        -9.63  1.230786e+09
# ...                          ...           ...
# 2016-12-31 19:10:00        -0.98  1.483211e+09
# 2016-12-31 20:10:00        -1.40  1.483215e+09
# 2016-12-31 21:10:00        -2.75  1.483219e+09
# 2016-12-31 22:10:00        -2.89  1.483222e+09
# 2016-12-31 23:10:00        -3.93  1.483226e+09
#
# [70091 rows x 2 columns]

# %%
day = 60*60*24
year = 365.2425*day

temp_df['Day sin'] = np.sin(temp_df['Seconds'] * (2* np.pi / day))
temp_df['Day cos'] = np.cos(temp_df['Seconds'] * (2 * np.pi / day))
temp_df['Year sin'] = np.sin(temp_df['Seconds'] * (2 * np.pi / year))
temp_df['Year cos'] = np.cos(temp_df['Seconds'] * (2 * np.pi / year))
temp_df.head()
# Out:
#                      Temperature       Seconds   Day sin   Day cos  Year sin  \
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09  0.258819  0.965926  0.010049
# 2009-01-01 02:00:00        -8.88  1.230775e+09  0.500000  0.866025  0.010766
# 2009-01-01 03:00:00        -8.81  1.230779e+09  0.707107  0.707107  0.011483
# 2009-01-01 04:00:00        -9.05  1.230782e+09  0.866025  0.500000  0.012199
# 2009-01-01 05:00:00        -9.63  1.230786e+09  0.965926  0.258819  0.012916
#
#                      Year cos
# Date Time
# 2009-01-01 01:00:00  0.999950
# 2009-01-01 02:00:00  0.999942
# 2009-01-01 03:00:00  0.999934
# 2009-01-01 04:00:00  0.999926
# 2009-01-01 05:00:00  0.999917

# %%
temp_df = temp_df.drop('Seconds', axis=1)
temp_df.head()
# Out:
#                      Temperature   Day sin   Day cos  Year sin  Year cos
# Date Time
# 2009-01-01 01:00:00        -8.05  0.258819  0.965926  0.010049  0.999950
# 2009-01-01 02:00:00        -8.88  0.500000  0.866025  0.010766  0.999942
# 2009-01-01 03:00:00        -8.81  0.707107  0.707107  0.011483  0.999934
# 2009-01-01 04:00:00        -9.05  0.866025  0.500000  0.012199  0.999926
# 2009-01-01 05:00:00        -9.63  0.965926  0.258819  0.012916  0.999917

# %%
def df_to_X_y2(df, window_size=6):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size][0]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X2, y2 = df_to_X_y2(temp_df)
X2.shape, y2.shape
# Out:
# ((70085, 6, 5), (70085,))

# %%
X2_train, y2_train = X2[:60000], y2[:60000]
X2_val, y2_val = X2[60000:65000], y2[60000:65000]
X2_test, y2_test = X2[65000:], y2[65000:]
X2_train.shape, y2_train.shape, X2_val.shape, y2_val.shape, X2_test.shape, y2_test.shape
# Out:
# ((60000, 6, 5), (60000,), (5000, 6, 5), (5000,), (5085, 6, 5), (5085,))

# %%
temp_training_mean = np.mean(X2_train[:, :, 0])
temp_training_std = np.std(X2_train[:, :, 0])
                           
def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - temp_training_mean) / temp_training_std
  return X

# %%
preprocess(X2_train)
preprocess(X2_val)
preprocess(X2_test) ;

# %%
model4 = Sequential()
model4.add(InputLayer((6, 5)))
model4.add(LSTM(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          17,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,449 (72.07 KB)
#  Trainable params: 18,449 (72.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp4 = ModelCheckpoint('model4.keras', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X2_train, y2_train, validation_data=(X2_val, y2_val), epochs=15, callbacks=[cp4])
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 35.0532 - root_mean_squared_error: 5.9206 - val_loss: 4.4486 - val_root_mean_squared_error: 2.1092
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 5.1071 - root_mean_squared_error: 2.2599 - val_loss: 1.7966 - val_root_mean_squared_error: 1.3404
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.7463 - root_mean_squared_error: 1.3215 - val_loss: 0.9052 - val_root_mean_squared_error: 0.9514
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 1.0266 - root_mean_squared_error: 1.0132 - val_loss: 0.6964 - val_root_mean_squared_error: 0.8345
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.7911 - root_mean_squared_error: 0.8894 - val_loss: 0.5689 - val_root_mean_squared_error: 0.7543
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.6481 - root_mean_squared_error: 0.8050 - val_loss: 0.4890 - val_root_mean_squared_error: 0.6993
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5729 - root_mean_squared_error: 0.7569 - val_loss: 0.4308 - val_root_mean_squared_error: 0.6563
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5449 - root_mean_squared_error: 0.7382 - val_loss: 0.4385 - val_root_mean_squared_error: 0.6622
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5328 - root_mean_squared_error: 0.7299 - val_loss: 0.4159 - val_root_mean_squared_error: 0.6449
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5295 - root_mean_squared_error: 0.7276 - val_loss: 0.4099 - val_root_mean_squared_error: 0.6402
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5252 - root_mean_squared_error: 0.7247 - val_loss: 0.4106 - val_root_mean_squared_error: 0.6408
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5232 - root_mean_squared_error: 0.7233 - val_loss: 0.4096 - val_root_mean_squared_error: 0.6400
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5196 - root_mean_squared_error: 0.7208 - val_loss: 0.4124 - val_root_mean_squared_error: 0.6422
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5175 - root_mean_squared_error: 0.7193 - val_loss: 0.4211 - val_root_mean_squared_error: 0.6490
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.5172 - root_mean_squared_error: 0.7192 - val_loss: 0.4087 - val_root_mean_squared_error: 0.6393

# %%
plot_predictions1(model4, X2_test, y2_test)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (      Predictions  Actuals
#  0       13.146658    13.46
#  1       12.751036    12.93
#  2       12.338908    12.43
#  3       12.025536    12.17
#  4       12.181486    11.55
#  ...           ...      ...
#  5080    -1.023966    -0.98
#  5081    -1.371778    -1.40
#  5082    -1.656007    -2.75
#  5083    -3.094354    -2.89
#  5084    -3.077546    -3.93
#
#  [5085 rows x 2 columns],
#  0.4655648957256597)

# %%
p_temp_df = pd.concat([df['p (mbar)'], temp_df], axis=1)
p_temp_df.head()
# Out:
#                      p (mbar)  Temperature   Day sin   Day cos  Year sin  \
# Date Time
# 2009-01-01 01:00:00    996.50        -8.05  0.258819  0.965926  0.010049
# 2009-01-01 02:00:00    996.62        -8.88  0.500000  0.866025  0.010766
# 2009-01-01 03:00:00    996.84        -8.81  0.707107  0.707107  0.011483
# 2009-01-01 04:00:00    996.99        -9.05  0.866025  0.500000  0.012199
# 2009-01-01 05:00:00    997.46        -9.63  0.965926  0.258819  0.012916
#
#                      Year cos
# Date Time
# 2009-01-01 01:00:00  0.999950
# 2009-01-01 02:00:00  0.999942
# 2009-01-01 03:00:00  0.999934
# 2009-01-01 04:00:00  0.999926
# 2009-01-01 05:00:00  0.999917

# %%
def df_to_X_y3(df, window_size=7):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = [df_as_np[i+window_size][0], df_as_np[i+window_size][1]]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X3, y3 = df_to_X_y3(p_temp_df)
X3.shape, y3.shape
# Out:
# ((70084, 7, 6), (70084, 2))

# %%
X3_train, y3_train = X3[:60000], y3[:60000]
X3_val, y3_val = X3[60000:65000], y3[60000:65000]
X3_test, y3_test = X3[65000:], y3[65000:]
X3_train.shape, y3_train.shape, X3_val.shape, y3_val.shape, X3_test.shape, y3_test.shape
# Out:
# ((60000, 7, 6), (60000, 2), (5000, 7, 6), (5000, 2), (5084, 7, 6), (5084, 2))

# %%
p_training_mean3 = np.mean(X3_train[:, :, 0])
p_training_std3 = np.std(X3_train[:, :, 0])

temp_training_mean3 = np.mean(X3_train[:, :, 1])
temp_training_std3 = np.std(X3_train[:, :, 1])

def preprocess3(X):
  X[:, :, 0] = (X[:, :, 0] - p_training_mean3) / p_training_std3
  X[:, :, 1] = (X[:, :, 1] - temp_training_mean3) / temp_training_std3

def preprocess_output3(y):
  y[:, 0] = (y[:, 0] - p_training_mean3) / p_training_std3
  y[:, 1] = (y[:, 1] - temp_training_mean3) / temp_training_std3
  return y

# %%
preprocess3(X3_train)
preprocess3(X3_val)
preprocess3(X3_test)

# %%
preprocess_output3(y3_train)
preprocess_output3(y3_val)
preprocess_output3(y3_test)
# Out:
# array([[-0.7934386 ,  0.41245076],
#        [-0.76312281,  0.35368268],
#        [-0.72189335,  0.32312327],
#        ...,
#        [ 1.48145784, -1.43051636],
#        [ 1.41597574, -1.44697142],
#        [ 1.35049365, -1.56920903]])

# %%
model5 = Sequential()
model5.add(InputLayer((7, 6)))
model5.add(LSTM(64))
model5.add(Dense(8, 'relu'))
model5.add(Dense(2, 'linear'))

model5.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          18,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 2)                   │              18 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,714 (73.10 KB)
#  Trainable params: 18,714 (73.10 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp5 = ModelCheckpoint('model5.keras', save_best_only=True)
model5.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model5.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=15, callbacks=[cp5])
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.1703 - root_mean_squared_error: 0.4127 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1810
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0251 - root_mean_squared_error: 0.1583 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1248
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0760
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0702
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0058 - root_mean_squared_error: 0.0761 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0662
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0645
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0629
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0051 - root_mean_squared_error: 0.0712 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0624
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0703 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0623
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0698 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0048 - root_mean_squared_error: 0.0694 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0609
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0621
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0600

# %%
def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X)
  p_preds, temp_preds = predictions[:, 0], predictions[:, 1]
  p_actuals, temp_actuals = y[:, 0], y[:, 1]
  df = pd.DataFrame(data={'Temperature Predictions': temp_preds,
                          'Temperature Actuals':temp_actuals,
                          'Pressure Predictions': p_preds,
                          'Pressure Actuals': p_actuals
                          })
  plt.plot(df['Temperature Predictions'][start:end])
  plt.plot(df['Temperature Actuals'][start:end])
  plt.plot(df['Pressure Predictions'][start:end])
  plt.plot(df['Pressure Actuals'][start:end])
  # plt.legend()
  return df[start:end]

# %%
plot_predictions2(model5, X3_test, y3_test)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#     Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                  0.392043             0.412451             -0.788497
# 1                  0.340443             0.353683             -0.778940
# 2                  0.296033             0.323123             -0.743700
# 3                  0.299067             0.250251             -0.689033
# 4                  0.252956             0.254952             -0.597885
# ..                      ...                  ...                   ...
# 95                 0.686094             0.716869             -0.422984
# 96                 0.641114             0.687485             -0.421204
# 97                 0.619171             0.663978             -0.401078
# 98                 0.617947             0.641646             -0.393179
# 99                 0.630243             0.653400             -0.386482
#
#     Pressure Actuals
# 0          -0.793439
# 1          -0.763123
# 2          -0.721893
# 3          -0.652773
# 4          -0.652773
# ..               ...
# 95         -0.416310
# 96         -0.399333
# 97         -0.399333
# 98         -0.400546
# 99         -0.369018
#
# [100 rows x 4 columns]

# %%
def postprocess_temp(arr):
  arr = (arr*temp_training_std3) + temp_training_mean3
  return arr

def postprocess_p(arr):
  arr = (arr*p_training_std3) + p_training_mean3
  return arr

# %%
def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X)
  p_preds, temp_preds = postprocess_p(predictions[:, 0]), postprocess_temp(predictions[:, 1])
  p_actuals, temp_actuals = postprocess_p(y[:, 0]), postprocess_temp(y[:, 1])
  df = pd.DataFrame(data={'Temperature Predictions': temp_preds,
                          'Temperature Actuals':temp_actuals,
                          'Pressure Predictions': p_preds,
                          'Pressure Actuals': p_actuals
                          })
  plt.plot(df['Temperature Predictions'][start:end])
  plt.plot(df['Temperature Actuals'][start:end])
  plt.plot(df['Pressure Predictions'][start:end])
  plt.plot(df['Pressure Actuals'][start:end])
  return df[start:end]

# %%
post_processed_df = plot_predictions2(model5, X3_test, y3_test)
post_processed_df
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#     Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                 12.756371                12.93            982.470750
# 1                 12.317355                12.43            982.549564
# 2                 11.939516                12.17            982.840173
# 3                 11.965330                11.55            983.290983
# 4                 11.573013                11.59            984.042638
# ..                      ...                  ...                   ...
# 95                15.258160                15.52            985.484963
# 96                14.875474                15.27            985.499643
# 97                14.688784                15.07            985.665611
# 98                14.678367                14.88            985.730749
# 99                14.782983                14.98            985.785980
#
#     Pressure Actuals
# 0             982.43
# 1             982.68
# 2             983.02
# 3             983.59
# 4             983.59
# ..               ...
# 95            985.54
# 96            985.68
# 97            985.68
# 98            985.67
# 99            985.93
#
# [100 rows x 4 columns]

# %%
start, end = 0, 100
plt.plot(post_processed_df['Temperature Predictions'][start:end])
plt.plot(post_processed_df['Temperature Actuals'][start:end])

# %%
plt.plot(post_processed_df['Pressure Predictions'][start:end])
plt.plot(post_processed_df['Pressure Actuals'][start:end])

# %% [markdown]
# ### Model 6

# %%
model6 = Sequential()
model6.add(InputLayer((7, 6)))
model6.add(LSTM(32, return_sequences=True))
model6.add(LSTM(64))
model6.add(Dense(8, 'relu'))
model6.add(Dense(2, 'linear'))

model6.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 7, 32)               │           4,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 2)                   │              18 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,362 (118.60 KB)
#  Trainable params: 30,362 (118.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp6 = ModelCheckpoint('model6.keras', save_best_only=True)
model6.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model6.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=15, callbacks=[cp6])
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - loss: 0.1445 - root_mean_squared_error: 0.3801 - val_loss: 0.0437 - val_root_mean_squared_error: 0.2091
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0313 - root_mean_squared_error: 0.1770 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0108 - root_mean_squared_error: 0.1041 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0898
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0084 - root_mean_squared_error: 0.0916 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0804
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0070 - root_mean_squared_error: 0.0834 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0738
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0061 - root_mean_squared_error: 0.0780 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0056 - root_mean_squared_error: 0.0751 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0664
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0054 - root_mean_squared_error: 0.0737 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0053 - root_mean_squared_error: 0.0729 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0051 - root_mean_squared_error: 0.0716 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0626
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0050 - root_mean_squared_error: 0.0710 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0615
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0050 - root_mean_squared_error: 0.0705 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0616
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.0049 - root_mean_squared_error: 0.0704 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0610

# %%
post_processed_df6 = plot_predictions2(model6, X3_test, y3_test)
post_processed_df6
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#     Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                 12.807804                12.93            982.557489
# 1                 12.414647                12.43            982.641871
# 2                 12.050309                12.17            982.892033
# 3                 12.076499                11.55            983.290259
# 4                 11.636139                11.59            983.987690
# ..                      ...                  ...                   ...
# 95                15.285875                15.52            985.607373
# 96                14.931192                15.27            985.599840
# 97                14.753969                15.07            985.714817
# 98                14.770171                14.88            985.765028
# 99                14.901024                14.98            985.808480
#
#     Pressure Actuals
# 0             982.43
# 1             982.68
# 2             983.02
# 3             983.59
# 4             983.59
# ..               ...
# 95            985.54
# 96            985.68
# 97            985.68
# 98            985.67
# 99            985.93
#
# [100 rows x 4 columns]

# %%
start, end = 0, 100
plt.plot(post_processed_df6['Temperature Predictions'][start:end])
plt.plot(post_processed_df6['Temperature Actuals'][start:end])

# %%
plt.plot(post_processed_df6['Pressure Predictions'][start:end])
plt.plot(post_processed_df6['Pressure Actuals'][start:end])

# %% [markdown]
# ### Model 7

# %%
model7 = Sequential()
model7.add(InputLayer((7, 6)))
model7.add(Conv1D(64, kernel_size=2, activation='relu'))
model7.add(Flatten())
model7.add(Dense(8, 'relu'))
model7.add(Dense(2, 'linear'))
model7.summary()

cp7 = ModelCheckpoint('model7.keras', save_best_only=True)
model7.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)                    │ (None, 6, 64)               │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 384)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 8)                   │           3,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 2)                   │              18 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,930 (15.35 KB)
#  Trainable params: 3,930 (15.35 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model7.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp7])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1199 - root_mean_squared_error: 0.3463 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1390
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0820
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0756
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0066 - root_mean_squared_error: 0.0813 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0718
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0698
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0682
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0660
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0055 - root_mean_squared_error: 0.0741 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0653

# %%
post_processed_df7 = plot_predictions2(model7, X3_test, y3_test)
post_processed_df7
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
#     Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                 12.802086                12.93            982.443275
# 1                 12.361408                12.43            982.506088
# 2                 12.085207                12.17            982.745537
# 3                 12.278380                11.55            983.153521
# 4                 11.809756                11.59            983.832076
# ..                      ...                  ...                   ...
# 95                15.376435                15.52            985.358553
# 96                15.011645                15.27            985.340423
# 97                14.705875                15.07            985.390494
# 98                14.610779                14.88            985.604162
# 99                14.834628                14.98            985.659742
#
#     Pressure Actuals
# 0             982.43
# 1             982.68
# 2             983.02
# 3             983.59
# 4             983.59
# ..               ...
# 95            985.54
# 96            985.68
# 97            985.68
# 98            985.67
# 99            985.93
#
# [100 rows x 4 columns]

# %%
start, end = 0, 100
plt.plot(post_processed_df7['Temperature Predictions'][start:end])
plt.plot(post_processed_df7['Temperature Actuals'][start:end])

# %%
plt.plot(post_processed_df7['Pressure Predictions'][start:end])
plt.plot(post_processed_df7['Pressure Actuals'][start:end])

# %%
end_time = time.time()
total_time = end_time - start_time
print(f"This notebook took {total_time/60:.3f} minutes to run")
# Out:
# This notebook took 6.137 minutes to run

# %% [markdown]
# # SHAP for Regession - Support Vector Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import shap
import time 

from tabulate import tabulate
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.svm import SVR
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

total_start_time = time.time()
warnings.filterwarnings('ignore')

# %%
# Import Data
# set the fule URl and filename
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'
filename = 'wine.csv'

# Check if the file is in the current directory
try:
    wine = pd.read_csv(filename)
except FileNotFoundError:
    print(f'Downloading {filename}from {url} ...')
    wine = pd.read_csv(url, sep=";")
    wine.to_csv(filename, index=False)
    print('Download complete!')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
summary = wine.describe().transpose().round(2)
summary = summary.drop("count", axis=1)

# create a markdown table
markdown_table = tabulate(
    summary, headers='keys', tablefmt='pipe'
)
print(markdown_table)
# Out:
# |                      |   mean |   std |   min |    25% |    50% |    75% |    max |
# |:---------------------|-------:|------:|------:|-------:|-------:|-------:|-------:|
# | fixed acidity        |   6.85 |  0.84 |  3.8  |   6.3  |   6.8  |   7.3  |  14.2  |
# | volatile acidity     |   0.28 |  0.1  |  0.08 |   0.21 |   0.26 |   0.32 |   1.1  |
# | citric acid          |   0.33 |  0.12 |  0    |   0.27 |   0.32 |   0.39 |   1.66 |
# | residual sugar       |   6.39 |  5.07 |  0.6  |   1.7  |   5.2  |   9.9  |  65.8  |
# | chlorides            |   0.05 |  0.02 |  0.01 |   0.04 |   0.04 |   0.05 |   0.35 |
# | free sulfur dioxide  |  35.31 | 17.01 |  2    |  23    |  34    |  46    | 289    |
# | total sulfur dioxide | 138.36 | 42.5  |  9    | 108    | 134    | 167    | 440    |
# | density              |   0.99 |  0    |  0.99 |   0.99 |   0.99 |   1    |   1.04 |
# | pH                   |   3.19 |  0.15 |  2.72 |   3.09 |   3.18 |   3.28 |   3.82 |
# | sulphates            |   0.49 |  0.11 |  0.22 |   0.41 |   0.47 |   0.55 |   1.08 |
# | alcohol              |  10.51 |  1.23 |  8    |   9.5  |  10.4  |  11.4  |  14.2  |
# | quality              |   5.88 |  0.89 |  3    |   5    |   6    |   6    |   9    |

# %% [markdown]
# ## Fit a Regression Model with Support Vector Regression

# %%
y = wine['quality']
X = wine.drop('quality', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

# %%
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("svr", SVR())  # default kernel='rbf'
])

# %%
param_grid = {
    "svr__kernel": ["rbf", "linear"],
    "svr__C": [0.3, 1, 3, 10, 30],
    "svr__gamma": ["scale", 0.1, 0.03, 0.01],   # only used for 'rbf'
    "svr__epsilon": [0.01, 0.1, 0.3, 1.0],
}

# %%
cv = KFold(n_splits=10, shuffle=True, random_state=11)

# %%
search = GridSearchCV(
    pipe,
    param_grid=param_grid,
    scoring="neg_root_mean_squared_error",  # RMSE (negative because "higher is better" convention)
    cv=cv,
    n_jobs=-1
)

# %%
search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=11, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svr', SVR())]),
#              n_jobs=-1,
#              param_grid={'svr__C': [0.3, 1, 3, 10, 30],
#                          'svr__epsilon': [0.01, 0.1, 0.3, 1.0],
#                          'svr__gamma': ['scale', 0.1, 0.03, 0.01],
#                          'svr__kernel': ['rbf', 'linear']},
#              scoring='neg_root_mean_squared_error')

# %%
w = search.best_estimator_
print(w)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svr', SVR(C=3, epsilon=0.3, gamma=0.1))])

# %%
best_model = search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
rmse = mean_squared_error(y_test, y_pred)
mae  = mean_absolute_error(y_test, y_pred)
r2   = r2_score(y_test, y_pred)

print("Best params:", search.best_params_)
print(f"Test RMSE: {rmse:.3f} | MAE: {mae:.3f} | R²: {r2:.3f}")
# Out:
# Best params: {'svr__C': 3, 'svr__epsilon': 0.3, 'svr__gamma': 0.1, 'svr__kernel': 'rbf'}
# Test RMSE: 0.460 | MAE: 0.525 | R²: 0.427

# %% [markdown]
# ## SHAP Values

# %%
explainer = shap.Explainer(best_model.predict, X_train)

# %%
shap_values = explainer(X_test)
# Out:
# PermutationExplainer explainer:   3%|█▏                                             | 25/980 [09:02<5:59:53, 22.61s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 shap_values = explainer(X_test)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\shap\explainers\_permutation.py:100, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      89 def __call__(
#      90     self,
#      91     *args,
#    (...)
#      97     silent=False,
#      98 ):
#      99     """Explain the output of the model on the given arguments."""
# --> 100     return super().__call__(
#     101         *args,
#     102         max_evals=max_evals,
#     103         main_effects=main_effects,
#     104         error_bounds=error_bounds,
#     105         batch_size=batch_size,
#     106         outputs=outputs,
#     107         silent=silent,
#     108     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\shap\explainers\_explainer.py:366, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     364     feature_names = [[] for _ in range(len(args))]
#     365 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__ + " explainer", silent):
# --> 366     row_result = self.explain_row(
#     367         *row_args,
#     368         max_evals=max_evals,
#     369         main_effects=main_effects,
#     370         error_bounds=error_bounds,
#     371         batch_size=batch_size,
#     372         outputs=outputs,
#     373         silent=silent,
#     374         **kwargs,
#     375     )
#     376     values.append(row_result.get("values", None))
#     377     output_indices.append(row_result.get("output_indices", None))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\shap\explainers\_permutation.py:162, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     159     i += 1
#     161 # evaluate the masked model
# --> 162 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     164 if row_values is None:
#     165     row_values = np.zeros((len(fm),) + outputs.shape[1:])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\shap\utils\_masked_model.py:57, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      55 if len(masks.shape) == 1:
#      56     if getattr(self.masker, "supports_delta_masking", False):
# ---> 57         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      59     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      60     # input but the masker does not support delta masking
#      61     else:
#      62         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\shap\utils\_masked_model.py:209, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     206     batch_positions[i + 1] = batch_positions[i] + num_varying_rows[i]
#     208 # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 209 outputs = self.model(*subset_masked_inputs)
#     210 _assert_output_input_match(subset_masked_inputs, outputs)
#     212 if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\shap\models\_model.py:23, in Model.__call__(self, *args)
#      22 def __call__(self, *args):
# ---> 23     out = self.inner_model(*args)
#      24     is_tensor = safe_isinstance(out, "torch.Tensor")
#      25     out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\pipeline.py:788, in Pipeline.predict(self, X, **params)
#     786     for _, name, transform in self._iter(with_final=False):
#     787         Xt = transform.transform(Xt)
# --> 788     return self.steps[-1][1].predict(Xt, **params)
#     790 # metadata routing enabled
#     791 routed_params = process_routing(self, "predict", **params)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:438, in BaseLibSVM.predict(self, X)
#     436 X = self._validate_for_predict(X)
#     437 predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 438 return predict(X)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:457, in BaseLibSVM._dense_predict(self, X)
#     449         raise ValueError(
#     450             "X.shape[1] = %d should be equal to %d, "
#     451             "the number of samples at training time"
#     452             % (X.shape[1], self.shape_fit_[0])
#     453         )
#     455 svm_type = LIBSVM_IMPL.index(self._impl)
# --> 457 return libsvm.predict(
#     458     X,
#     459     self.support_,
#     460     self.support_vectors_,
#     461     self._n_support,
#     462     self._dual_coef_,
#     463     self._intercept_,
#     464     self._probA,
#     465     self._probB,
#     466     svm_type=svm_type,
#     467     kernel=kernel,
#     468     degree=self.degree,
#     469     coef0=self.coef0,
#     470     gamma=self._gamma,
#     471     cache_size=self.cache_size,
#     472 )
#
# KeyboardInterrupt:

# %%
shap.plots.waterfall(shap_values[0])

# %%
shap.plots.waterfall(shap_values[1])

# %%
shap.plots.beeswarm(shap_values)

# %%
total_end_time = time.time()

# %%
total_time = (total_end_time - total_start_time) / 60
print(f'It took {total_time:.2f} minutes for this notebook to run.')

# %%
# !python .__version__
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 python.__version__
#
# NameError: name 'python' is not defined
